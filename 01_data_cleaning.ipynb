# %%
import pandas as pd
import numpy as np
from datetime import datetime, date

# %%
pd.set_option('display.max_columns', None)
data = pd.read_csv('Terry_stops.csv')
data.head()
# Out:
#   Subject Age Group  Subject ID     GO / SC Num  Terry Stop ID  \
# 0                 -          -1  20140000120677          92317
# 1                 -          -1  20150000001463          28806
# 2                 -          -1  20150000001516          29599
# 3                 -          -1  20150000001670          32260
# 4                 -          -1  20150000001739          33155
#
#   Stop Resolution Weapon Type Officer ID  Officer YOB Officer Gender  \
# 0          Arrest        None     7500           1984              M
# 1   Field Contact        None     5670           1965              M
# 2   Field Contact        None     4844           1961              M
# 3   Field Contact        None     7539           1963              M
# 4   Field Contact        None     6973           1977              M
#
#                 Officer Race     Subject Perceived Race  \
# 0  Black or African American                      Asian
# 1                      White                          -
# 2                      White                      White
# 3                      White                          -
# 4                      White  Black or African American
#
#   Subject Perceived Gender        Reported Date Reported Time  \
# 0                     Male  2015-10-16T00:00:00      11:32:00
# 1                        -  2015-03-19T00:00:00      07:59:00
# 2                     Male  2015-03-21T00:00:00      19:12:00
# 3                        -  2015-04-01T00:00:00      04:55:00
# 4                     Male  2015-04-03T00:00:00      00:41:00
#
#   Initial Call Type Final Call Type Call Type             Officer Squad  \
# 0                 -               -         -  SOUTH PCT 1ST W - ROBERT
# 1                 -               -         -                       NaN
# 2                 -               -         -                       NaN
# 3                 -               -         -                       NaN
# 4                 -               -         -                       NaN
#
#   Arrest Flag Frisk Flag Precinct  Sector    Beat
# 0           N          N    South  O       O2
# 1           N          N        -       -       -
# 2           N          -        -       -       -
# 3           N          N        -       -       -
# 4           N          N        -       -       -

# %% [markdown]
# ## Initial Inspection of Data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48525 entries, 0 to 48524
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Subject Age Group         48525 non-null  object
#  1   Subject ID                48525 non-null  int64
#  2   GO / SC Num               48525 non-null  int64
#  3   Terry Stop ID             48525 non-null  int64
#  4   Stop Resolution           48525 non-null  object
#  5   Weapon Type               48525 non-null  object
#  6   Officer ID                48525 non-null  object
#  7   Officer YOB               48525 non-null  int64
#  8   Officer Gender            48525 non-null  object
#  9   Officer Race              48525 non-null  object
#  10  Subject Perceived Race    48525 non-null  object
#  11  Subject Perceived Gender  48525 non-null  object
#  12  Reported Date             48525 non-null  object
#  13  Reported Time             48525 non-null  object
#  14  Initial Call Type         48525 non-null  object
#  15  Final Call Type           48525 non-null  object
#  16  Call Type                 48525 non-null  object
#  17  Officer Squad             47919 non-null  object
#  18  Arrest Flag               48525 non-null  object
#  19  Frisk Flag                48525 non-null  object
#  20  Precinct                  48525 non-null  object
#  21  Sector                    48525 non-null  object
#  22  Beat                      48525 non-null  object
# dtypes: int64(4), object(19)
# memory usage: 8.5+ MB

# %%
# removing unnecessary columns from dataframe
df = data.drop(columns=['Subject ID', 'GO / SC Num', 'Terry Stop ID', 'Reported Time'], axis=1)

# %%
# Inspection of Data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48525 entries, 0 to 48524
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Subject Age Group         48525 non-null  object
#  1   Stop Resolution           48525 non-null  object
#  2   Weapon Type               48525 non-null  object
#  3   Officer ID                48525 non-null  object
#  4   Officer YOB               48525 non-null  int64
#  5   Officer Gender            48525 non-null  object
#  6   Officer Race              48525 non-null  object
#  7   Subject Perceived Race    48525 non-null  object
#  8   Subject Perceived Gender  48525 non-null  object
#  9   Reported Date             48525 non-null  object
#  10  Initial Call Type         48525 non-null  object
#  11  Final Call Type           48525 non-null  object
#  12  Call Type                 48525 non-null  object
#  13  Officer Squad             47919 non-null  object
#  14  Arrest Flag               48525 non-null  object
#  15  Frisk Flag                48525 non-null  object
#  16  Precinct                  48525 non-null  object
#  17  Sector                    48525 non-null  object
#  18  Beat                      48525 non-null  object
# dtypes: int64(1), object(18)
# memory usage: 7.0+ MB

# %%
df.describe()
# Out:
#         Officer YOB
# count  48525.000000
# mean    1983.091355
# std        9.083316
# min     1900.000000
# 25%     1978.000000
# 50%     1985.000000
# 75%     1990.000000
# max     1998.000000

# %%
#reformat col names 
df.rename(columns={'Subject Age Group':'subject_age_group', 'Stop Resolution':'stop_resolution', 'Weapon Type':'weapon_type', 'Officer ID':'officer_id',
       'Officer YOB':'officer_yob', 'Officer Gender':'officer_gender', 'Officer Race':'officer_race',
       'Subject Perceived Race':'subject_perceived_race', 'Subject Perceived Gender':'subject_perceived_gender', 'Reported Date':'reported_date',
       'Initial Call Type':'initial_call_type', 'Final Call Type':'final_call_type', 'Call Type':'call_type', 'Officer Squad': 'officer_squad',
       'Arrest Flag':'arrest_flag', 'Frisk Flag':'frisk_flag', 'Precinct':'precinct', 'Sector':'sector', 'Beat':'beat'}, inplace=True)

# %%
# Inspecting value counts for each column
for col in df.columns:
    try:
        print(df[col].value_counts())
    except:
        print(df[col].value_counts())   
    print('\n')
# Out:
# 26 - 35         16171
# 36 - 45         10345
# 18 - 25          9676
# 46 - 55          6276
# 56 and Above     2469
# 1 - 17           1991
# -                1597
# Name: subject_age_group, dtype: int64
#
#
# Field Contact               19716
# Offense Report              15860
# Arrest                      12041
# Referred for Prosecution      728
# Citation / Infraction         180
# Name: stop_resolution, dtype: int64
#
#
# None                                    32565
# -                                       13060
# Lethal Cutting Instrument                1482
# Knife/Cutting/Stabbing Instrument         707
# Handgun                                   300
# Firearm Other                             100
# Blunt Object/Striking Implement            93
# Club, Blackjack, Brass Knuckles            49
# Firearm                                    44
# Mace/Pepper Spray                          31
# Other Firearm                              27
# Firearm (unk type)                         15
# Taser/Stun Gun                             10
# Club                                        9
# None/Not Applicable                         9
# Fire/Incendiary Device                      8
# Rifle                                       7
# Shotgun                                     3
# Personal Weapons (hands, feet, etc.)        2
# Automatic Handgun                           2
# Brass Knuckles                              1
# Blackjack                                   1
# Name: weapon_type, dtype: int64
#
#
# 7456      430
# 7634      347
# 7773      333
# 7765      315
# 7758      313
#          ...
# 6993        1
# 5014        1
# 5445        1
# 6421        1
# 8761        1
# Name: officer_id, Length: 1225, dtype: int64
#
#
# 1986    3383
# 1987    3089
# 1984    2802
# 1991    2742
# 1992    2559
# 1985    2513
# 1990    2346
# 1988    2189
# 1989    2052
# 1982    1868
# 1983    1743
# 1979    1558
# 1993    1518
# 1981    1477
# 1995    1310
# 1971    1236
# 1978    1177
# 1976    1052
# 1977    1031
# 1994     964
# 1973     933
# 1980     840
# 1996     731
# 1967     721
# 1968     632
# 1970     612
# 1969     568
# 1974     566
# 1975     540
# 1997     486
# 1962     457
# 1964     439
# 1972     429
# 1965     420
# 1963     262
# 1966     228
# 1958     220
# 1961     215
# 1959     174
# 1960     161
# 1998      60
# 1954      44
# 1957      43
# 1900      35
# 1953      34
# 1955      21
# 1956      17
# 1948      11
# 1952       9
# 1949       5
# 1946       2
# 1951       1
# Name: officer_yob, dtype: int64
#
#
# M    42973
# F     5523
# N       29
# Name: officer_gender, dtype: int64
#
#
# White                            36522
# Hispanic or Latino                2827
# Two or More Races                 2791
# Asian                             2120
# Black or African American         1935
# Not Specified                     1513
# Nat Hawaiian/Oth Pac Islander      461
# American Indian/Alaska Native      321
# Unknown                             35
# Name: officer_race, dtype: int64
#
#
# White                                        23716
# Black or African American                    14465
# Unknown                                       2793
# -                                             1851
# Hispanic                                      1684
# Asian                                         1594
# American Indian or Alaska Native              1392
# Multi-Racial                                   809
# Other                                          152
# Native Hawaiian or Other Pacific Islander       69
# Name: subject_perceived_race, dtype: int64
#
#
# Male                                                         38119
# Female                                                        9801
# Unable to Determine                                            326
# -                                                              235
# Unknown                                                         37
# Gender Diverse (gender non-conforming and/or transgender)        7
# Name: subject_perceived_gender, dtype: int64
#
#
# 2015-10-01T00:00:00    101
# 2015-09-29T00:00:00     66
# 2015-05-28T00:00:00     57
# 2015-07-18T00:00:00     55
# 2019-04-26T00:00:00     54
#                       ...
# 2015-05-13T00:00:00      1
# 2015-03-28T00:00:00      1
# 2015-04-28T00:00:00      1
# 2015-03-24T00:00:00      1
# 2015-04-14T00:00:00      1
# Name: reported_date, Length: 2333, dtype: int64
#
#
# -                                                 13234
# SUSPICIOUS STOP - OFFICER INITIATED ONVIEW         3234
# SUSPICIOUS PERSON, VEHICLE OR INCIDENT             3098
# DISTURBANCE, MISCELLANEOUS/OTHER                   2506
# ASLT - IP/JO - WITH OR W/O WPNS (NO SHOOTINGS)     2108
#                                                   ...
# PHONE - OBSCENE OR NUISANCE PHONE CALLS               1
# ESCAPE - PRISONER                                     1
# MISSING - (ALZHEIMER, ENDANGERED, ELDERLY)            1
# MISSING - ADULT                                       1
# DEMONSTRATIONS                                        1
# Name: initial_call_type, Length: 168, dtype: int64
#
#
# -                                           13234
# --SUSPICIOUS CIRCUM. - SUSPICIOUS PERSON     3920
# --PROWLER - TRESPASS                         3406
# --DISTURBANCE - OTHER                        2802
# --ASSAULTS, OTHER                            2386
#                                             ...
# --DEMO MGMNT (CONTROL TACTICS USED)             1
# -OFF DUTY EMPLOYMENT                            1
# --HARBOR - ASSIST BOATER (NON EMERG)            1
# TRAF - ELUDING POLICE                           1
# PROWLER                                         1
# Name: final_call_type, Length: 211, dtype: int64
#
#
# 911                              22127
# -                                13234
# ONVIEW                            9364
# TELEPHONE OTHER, NOT 911          3429
# ALARM CALL (NOT POLICE ALARM)      361
# TEXT MESSAGE                         9
# SCHEDULED EVENT (RECURRING)          1
# Name: call_type, dtype: int64
#
#
# TRAINING - FIELD TRAINING SQUAD                        5210
# WEST PCT 1ST W - DAVID/MARY                            1583
# WEST PCT 2ND W - D/M RELIEF                            1041
# SOUTHWEST PCT 2ND W - FRANK                            1007
# WEST PCT 1ST W - KING/QUEEN                             899
#                                                        ...
# COMM - INTERNET AND TELEPHONE REPORTING (ITRU)            1
# COMMUNITY OUTREACH - YOUTH VIOLENCE -SCHOOLS DETAIL       1
# RECORDS - DAY SHIFT                                       1
# ZOLD CRIME ANALYSIS UNIT - ANALYSTS                       1
# TRAF - MOTORCYCLE UNIT - T2 SQUAD                         1
# Name: officer_squad, Length: 173, dtype: int64
#
#
# N    44692
# Y     3833
# Name: arrest_flag, dtype: int64
#
#
# N    37056
# Y    10991
# -      478
# Name: frisk_flag, dtype: int64
#
#
# West         11913
# North        10672
# -             9930
# East          6389
# South         5816
# Southwest     2320
# SouthWest     1227
# Unknown        200
# OOJ             37
# FK ERROR        21
# Name: precinct, dtype: int64
#
#
# -         10141
# E          2337
# M          2270
# N          2191
# K          1890
# K          1762
# B          1658
# L          1639
# D          1512
# R          1455
# F          1378
# M          1365
# S          1348
# U          1302
# D          1249
# O          1161
# J          1119
# G          1087
# C          1037
# E           993
# Q           967
# W           941
# Q           894
# N           768
# F           755
# R           684
# O           655
# B           601
# S           514
# G           499
# U           489
# L           482
# W           471
# C           435
# J           423
# 99           53
# Name: sector, dtype: int64
#
#
# -         10075
# N3         1175
# E2         1092
# K3         1059
# M2          852
#           ...
# N1           86
# 99           53
# 99           35
# OOJ          25
# S             2
# Name: beat, Length: 107, dtype: int64

# %% [markdown]
# ## Data Cleaning Episode 1: The NaN Menace

# %% [markdown]
# I begin the data cleaning process by inspecting columns and their NaN's to determine how to handle them. Some were converted to the 'None' value that was already present in the column values. Others were left in because they would not be used in dataframe used for modelling.

# %%
# Some Columns have an '-' so will convert to NaN
#  and then inspect for NaN Values

df.replace('-', np.nan, inplace=True)
df.isna().sum()
# Out:
# subject_age_group            1597
# stop_resolution                 0
# weapon_type                 13060
# officer_id                     24
# officer_yob                     0
# officer_gender                  0
# officer_race                    0
# subject_perceived_race       1851
# subject_perceived_gender      235
# reported_date                   0
# initial_call_type           13234
# final_call_type             13234
# call_type                   13234
# officer_squad                 606
# arrest_flag                     0
# frisk_flag                    478
# precinct                     9930
# sector                      10141
# beat                        10075
# dtype: int64

# %%
# Subject Age Group (10 year increments) as reported by the officer.

df['subject_age_group'].value_counts(dropna=False)
# Out:
# 26 - 35         16171
# 36 - 45         10345
# 18 - 25          9676
# 46 - 55          6276
# 56 and Above     2469
# 1 - 17           1991
# NaN              1597
# Name: subject_age_group, dtype: int64

# %%
# Convert NaN to 'Not Specified'
df['subject_age_group'] = df['subject_age_group'].replace(np.nan,'Not Specified')

# %%
# Type of weapon, if any, identified during a search or frisk of the subject. Indicates "None" if no weapons was found.

df['weapon_type'].value_counts(dropna=False)
# Out:
# None                                    32565
# NaN                                     13060
# Lethal Cutting Instrument                1482
# Knife/Cutting/Stabbing Instrument         707
# Handgun                                   300
# Firearm Other                             100
# Blunt Object/Striking Implement            93
# Club, Blackjack, Brass Knuckles            49
# Firearm                                    44
# Mace/Pepper Spray                          31
# Other Firearm                              27
# Firearm (unk type)                         15
# Taser/Stun Gun                             10
# None/Not Applicable                         9
# Club                                        9
# Fire/Incendiary Device                      8
# Rifle                                       7
# Shotgun                                     3
# Automatic Handgun                           2
# Personal Weapons (hands, feet, etc.)        2
# Brass Knuckles                              1
# Blackjack                                   1
# Name: weapon_type, dtype: int64

# %%
# Converting NaN's to 'None' for weapon type column
df['weapon_type'] = df['weapon_type'].replace(np.nan,'None')

# Convert 'None/Not Applicable' to 'None' for alignment
df['weapon_type'] = df['weapon_type'].replace('None/Not Applicable','None')

# %%
# Key identifying unique officers in the dataset.

df['officer_id'].value_counts(dropna=False)
# Out:
# 7456      430
# 7634      347
# 7773      333
# 7765      315
# 7758      313
#          ...
# 8543        1
# 5445        1
# 6022        1
# 6421        1
# 6363        1
# Name: officer_id, Length: 1225, dtype: int64

# %%
# Perceived race of the subject, as reported by the officer.

df['subject_perceived_race'].value_counts(dropna=False)
# Out:
# White                                        23716
# Black or African American                    14465
# Unknown                                       2793
# NaN                                           1851
# Hispanic                                      1684
# Asian                                         1594
# American Indian or Alaska Native              1392
# Multi-Racial                                   809
# Other                                          152
# Native Hawaiian or Other Pacific Islander       69
# Name: subject_perceived_race, dtype: int64

# %%
# Convert NaN's to Unknown so that they are aligned

df['subject_perceived_race'] = df['subject_perceived_race'].replace(np.nan,'Unknown')

# %%
# Perceived gender of the subject, as reported by the officer.

df['subject_perceived_gender'].value_counts(dropna=False)
# Out:
# Male                                                         38119
# Female                                                        9801
# Unable to Determine                                            326
# NaN                                                            235
# Unknown                                                         37
# Gender Diverse (gender non-conforming and/or transgender)        7
# Name: subject_perceived_gender, dtype: int64

# %%
#convert NaN's and 'Unable to determine' to 'Unknown' so that they are aligned

df['subject_perceived_gender'] = df['subject_perceived_gender'].replace(np.nan,'Unknown')
df['subject_perceived_gender'] = df['subject_perceived_gender'].replace('Unable to Determine','Unknown')

# %%
# Initial classification of the call as assigned by 911

df['initial_call_type'].value_counts(dropna=False)
# Out:
# NaN                                               13234
# SUSPICIOUS STOP - OFFICER INITIATED ONVIEW         3234
# SUSPICIOUS PERSON, VEHICLE OR INCIDENT             3098
# DISTURBANCE, MISCELLANEOUS/OTHER                   2506
# ASLT - IP/JO - WITH OR W/O WPNS (NO SHOOTINGS)     2108
#                                                   ...
# PHONE - OBSCENE OR NUISANCE PHONE CALLS               1
# ESCAPE - PRISONER                                     1
# MISSING - (ALZHEIMER, ENDANGERED, ELDERLY)            1
# MISSING - ADULT                                       1
# REQUEST TO WATCH                                      1
# Name: initial_call_type, Length: 168, dtype: int64

# %%
# Final classification of the call as assigned by the primary officer closing the event.

df['final_call_type'].value_counts(dropna=False)
# Out:
# NaN                                                13234
# --SUSPICIOUS CIRCUM. - SUSPICIOUS PERSON            3920
# --PROWLER - TRESPASS                                3406
# --DISTURBANCE - OTHER                               2802
# --ASSAULTS, OTHER                                   2386
#                                                    ...
# FIGHT - VERBAL/ORAL (NO WEAPONS)                       1
# MVC - UNK INJURIES                                     1
# NOISE - DIST, GENERAL (CONST, RESID, BALL PLAY)        1
# BIAS -RACIAL, POLITICAL, SEXUAL MOTIVATION             1
# WARRANT PICKUP - FROM OTHER AGENCY                     1
# Name: final_call_type, Length: 211, dtype: int64

# %%
# How the call was received by the communication center.

df['call_type'].value_counts(dropna=False)
# Out:
# 911                              22127
# NaN                              13234
# ONVIEW                            9364
# TELEPHONE OTHER, NOT 911          3429
# ALARM CALL (NOT POLICE ALARM)      361
# TEXT MESSAGE                         9
# SCHEDULED EVENT (RECURRING)          1
# Name: call_type, dtype: int64

# %%
# Functional squad assignment (not budget) of the officer as reported by the Data Analytics Platform (DAP).

df['officer_squad'].value_counts(dropna=False)
# Out:
# TRAINING - FIELD TRAINING SQUAD                   5210
# WEST PCT 1ST W - DAVID/MARY                       1583
# WEST PCT 2ND W - D/M RELIEF                       1041
# SOUTHWEST PCT 2ND W - FRANK                       1007
# WEST PCT 1ST W - KING/QUEEN                        899
#                                                   ...
# BURG/THEFT/JUV - NORTH                               1
# BURG/THEFT/JUV - WEST                                1
# COMM - INTERNET AND TELEPHONE REPORTING (ITRU)       1
# TRAF - MOTORCYCLE UNIT - T3 SQUAD                    1
# TRAINING - ADVANCED - SQUAD C                        1
# Name: officer_squad, Length: 174, dtype: int64

# %%
# Indicator of whether a "frisk" was conducted, by the officer, of the subject, during the Terry Stop.
df['frisk_flag'].value_counts(dropna=False)
# Out:
# N      37056
# Y      10991
# NaN      478
# Name: frisk_flag, dtype: int64

# %%
# Dropping NaN's from frisk flag column bc it only represents .9% of the data set and convert column to object type
df = df.dropna(how='any',subset=['frisk_flag'])
df['frisk_flag'] = df['frisk_flag'].astype('object')

# %%
# Precinct of the address associated with the underlying Computer Aided Dispatch (CAD) event. 
# Not necessarily where the Terry Stop occurred.

df['precinct'].value_counts(dropna=False)
# Out:
# West         11821
# North        10559
# NaN           9793
# East          6346
# South         5754
# Southwest     2293
# SouthWest     1227
# Unknown        196
# OOJ             37
# FK ERROR        21
# Name: precinct, dtype: int64

# %%
# Sector of the address associated with the underlying Computer Aided Dispatch (CAD) event. 
# Not necessarily where the Terry Stop occurred.

df['sector'].value_counts(dropna=False)
# Out:
# NaN       10000
# E          2313
# M          2234
# N          2156
# K          1889
# K          1734
# B          1642
# L          1606
# D          1498
# R          1438
# M          1365
# F          1363
# S          1328
# U          1285
# D          1249
# O          1136
# J          1107
# G          1077
# C          1028
# E           993
# Q           954
# W           929
# Q           894
# N           768
# F           755
# R           684
# O           655
# B           601
# S           514
# G           499
# U           489
# L           482
# W           471
# C           435
# J           423
# 99           53
# Name: sector, dtype: int64

# %%
# Beat of the address associated with the underlying Computer Aided Dispatch (CAD) event. 
# Not necessarily where the Terry Stop occurred.

df['beat'].value_counts(dropna=False)
# Out:
# NaN       9934
# N3        1154
# E2        1080
# K3        1058
# M2         842
#           ...
# N1          86
# 99          53
# 99          35
# OOJ         25
# S            2
# Name: beat, Length: 107, dtype: int64

# %% [markdown]
# ## Data Cleaning Episode 2: The Attack of the Converts

# %% [markdown]
# The next part of the data cleaning involves converting the values in columns, the data type of the columns, and the removal of any outliers in the data. I also add a month and year column using the reported date column. Finally, I convert the arrest flag frisk flag columns from Y:N to 1:0.

# %%
# Convert Officer YOB to Age

df['officer_yob'] = 2021 - df['officer_yob']

# %%
# rename officer_yob column to officer age

df.rename(columns={'officer_yob':'officer_age'}, inplace=True)

# %%
# Inspecting age outliers

df.nlargest(50,['officer_age'])
# Out:
#       subject_age_group        stop_resolution  \
# 1048      Not Specified          Field Contact
# 1049      Not Specified          Field Contact
# 1050      Not Specified          Field Contact
# 1069      Not Specified          Field Contact
# 3634            18 - 25          Field Contact
# 7259            18 - 25          Field Contact
# 9291            18 - 25                 Arrest
# 11351           18 - 25          Field Contact
# 11912           18 - 25          Field Contact
# 12551           18 - 25         Offense Report
# 20801           26 - 35          Field Contact
# 25203           26 - 35                 Arrest
# 25527           26 - 35                 Arrest
# 27061           26 - 35          Field Contact
# 27548           26 - 35          Field Contact
# 28277           26 - 35          Field Contact
# 28299           26 - 35          Field Contact
# 30769           36 - 45          Field Contact
# 31224           36 - 45          Field Contact
# 36789           36 - 45          Field Contact
# 37070           36 - 45          Field Contact
# 37113           36 - 45                 Arrest
# 37142           36 - 45          Field Contact
# 37157           36 - 45         Offense Report
# 37233           36 - 45          Field Contact
# 38594           36 - 45          Field Contact
# 39003           36 - 45          Field Contact
# 39069           36 - 45          Field Contact
# 39714           36 - 45          Field Contact
# 44481           46 - 55          Field Contact
# 44640           46 - 55         Offense Report
# 45213           46 - 55          Field Contact
# 45771           46 - 55          Field Contact
# 47346      56 and Above         Offense Report
# 48253      56 and Above          Field Contact
# 3932            18 - 25          Field Contact
# 5391            18 - 25          Field Contact
# 182       Not Specified         Offense Report
# 4602            18 - 25  Citation / Infraction
# 4603            18 - 25  Citation / Infraction
# 4604            18 - 25  Citation / Infraction
# 4834            18 - 25         Offense Report
# 14331           26 - 35         Offense Report
# 30286           36 - 45         Offense Report
# 30287           36 - 45         Offense Report
# 40407           46 - 55  Citation / Infraction
# 40471           46 - 55         Offense Report
# 46320      56 and Above         Offense Report
# 4638            18 - 25         Offense Report
# 7672            18 - 25          Field Contact
#
#                              weapon_type officer_id  officer_age  \
# 1048                                None        NaN          121
# 1049                                None        NaN          121
# 1050                                None        NaN          121
# 1069                                None        NaN          121
# 3634                                None         -9          121
# 7259                                None         -9          121
# 9291                                None         -9          121
# 11351                               None     IV70            121
# 11912                               None        NaN          121
# 12551                               None        NaN          121
# 20801                               None     8579            121
# 25203                               None        NaN          121
# 25527                               None        NaN          121
# 27061                               None     IV70            121
# 27548                               None     IV70            121
# 28277                               None        NaN          121
# 28299                               None        NaN          121
# 30769                               None         -9          121
# 31224                               None         -9          121
# 36789                               None        NaN          121
# 37070                               None        NaN          121
# 37113                               None        NaN          121
# 37142                               None        NaN          121
# 37157  Knife/Cutting/Stabbing Instrument     IV70            121
# 37233                               None        NaN          121
# 38594                               None        NaN          121
# 39003                               None        NaN          121
# 39069                               None        NaN          121
# 39714                               None        NaN          121
# 44481                               None        NaN          121
# 44640                               None        NaN          121
# 45213                               None        NaN          121
# 45771                               None        NaN          121
# 47346                               None     8579            121
# 48253                               None        NaN          121
# 3932                                None     4272             75
# 5391                                None     4272             75
# 182                                 None     3170             73
# 4602                                None     3170             73
# 4603                                None     3170             73
# 4604                                None     3170             73
# 4834                                None     3170             73
# 14331                               None     3170             73
# 30286                               None     3170             73
# 30287                               None     3170             73
# 40407                               None     3170             73
# 40471                               None     3170             73
# 46320                               None     3170             73
# 4638                                None     2768             72
# 7672                                None     6752             72
#
#       officer_gender officer_race            subject_perceived_race  \
# 1048               N      Unknown                           Unknown
# 1049               N      Unknown                           Unknown
# 1050               N      Unknown                           Unknown
# 1069               N      Unknown                             White
# 3634               N      Unknown         Black or African American
# 7259               N      Unknown                           Unknown
# 9291               N      Unknown                             White
# 11351              M      Unknown                           Unknown
# 11912              N      Unknown                             White
# 12551              N      Unknown  American Indian or Alaska Native
# 20801              M      Unknown                             White
# 25203              N      Unknown                             White
# 25527              N      Unknown                             White
# 27061              M      Unknown                           Unknown
# 27548              M      Unknown                             White
# 28277              N      Unknown                             White
# 28299              N      Unknown                             White
# 30769              N      Unknown                             White
# 31224              N      Unknown                             White
# 36789              N      Unknown                           Unknown
# 37070              N      Unknown                             White
# 37113              N      Unknown         Black or African American
# 37142              N      Unknown                           Unknown
# 37157              M      Unknown                             White
# 37233              N      Unknown                             White
# 38594              N      Unknown                             White
# 39003              N      Unknown                           Unknown
# 39069              N      Unknown                             White
# 39714              N      Unknown                           Unknown
# 44481              N      Unknown         Black or African American
# 44640              N      Unknown  American Indian or Alaska Native
# 45213              N      Unknown                             White
# 45771              N      Unknown                             White
# 47346              M      Unknown                          Hispanic
# 48253              N      Unknown                           Unknown
# 3932               M        Asian                             White
# 5391               M        Asian         Black or African American
# 182                M        White                      Multi-Racial
# 4602               M        White                             White
# 4603               M        White                             White
# 4604               M        White                             White
# 4834               M        White         Black or African American
# 14331              M        White                          Hispanic
# 30286              M        White                             White
# 30287              M        White                             White
# 40407              M        White                             White
# 40471              M        White                             White
# 46320              M        White                             Asian
# 4638               M        White         Black or African American
# 7672               M        White         Black or African American
#
#       subject_perceived_gender        reported_date  \
# 1048                   Unknown  2019-07-27T00:00:00
# 1049                   Unknown  2019-07-27T00:00:00
# 1050                   Unknown  2019-07-27T00:00:00
# 1069                      Male  2019-09-10T00:00:00
# 3634                      Male  2015-05-19T00:00:00
# 7259                    Female  2017-06-06T00:00:00
# 9291                      Male  2018-02-07T00:00:00
# 11351                     Male  2019-05-30T00:00:00
# 11912                   Female  2019-11-27T00:00:00
# 12551                   Female  2019-10-29T00:00:00
# 20801                   Female  2018-05-21T00:00:00
# 25203                   Female  2019-08-15T00:00:00
# 25527                     Male  2019-10-23T00:00:00
# 27061                     Male  2019-05-20T00:00:00
# 27548                     Male  2019-05-20T00:00:00
# 28277                     Male  2019-11-02T00:00:00
# 28299                     Male  2019-11-10T00:00:00
# 30769                   Female  2016-01-02T00:00:00
# 31224                     Male  2016-09-14T00:00:00
# 36789                   Female  2019-10-28T00:00:00
# 37070                   Female  2019-11-22T00:00:00
# 37113                     Male  2019-06-06T00:00:00
# 37142                   Female  2019-07-09T00:00:00
# 37157                     Male  2019-05-14T00:00:00
# 37233                     Male  2019-07-21T00:00:00
# 38594                     Male  2019-11-22T00:00:00
# 39003                   Female  2019-09-30T00:00:00
# 39069                     Male  2019-11-10T00:00:00
# 39714                     Male  2019-10-24T00:00:00
# 44481                     Male  2019-07-13T00:00:00
# 44640                   Female  2019-10-23T00:00:00
# 45213                     Male  2019-09-22T00:00:00
# 45771                     Male  2019-09-29T00:00:00
# 47346                     Male  2018-07-10T00:00:00
# 48253                     Male  2019-09-22T00:00:00
# 3932                      Male  2015-09-10T00:00:00
# 5391                      Male  2016-02-22T00:00:00
# 182                    Unknown  2015-07-14T00:00:00
# 4602                      Male  2015-07-20T00:00:00
# 4603                    Female  2015-07-20T00:00:00
# 4604                      Male  2015-07-20T00:00:00
# 4834                    Female  2015-09-06T00:00:00
# 14331                     Male  2015-06-12T00:00:00
# 30286                     Male  2015-08-12T00:00:00
# 30287                     Male  2015-08-11T00:00:00
# 40407                   Female  2015-07-20T00:00:00
# 40471                     Male  2015-08-12T00:00:00
# 46320                     Male  2015-08-13T00:00:00
# 4638                      Male  2015-07-29T00:00:00
# 7672                   Unknown  2017-02-04T00:00:00
#
#                                     initial_call_type  \
# 1048                                              NaN
# 1049                                              NaN
# 1050                                              NaN
# 1069                                              NaN
# 3634                                              NaN
# 7259                                              NaN
# 9291                                              NaN
# 11351                                             NaN
# 11912                                             NaN
# 12551                                             NaN
# 20801                                             NaN
# 25203                                             NaN
# 25527                                             NaN
# 27061                                             NaN
# 27548                                             NaN
# 28277                                             NaN
# 28299                                             NaN
# 30769                                             NaN
# 31224                                             NaN
# 36789                                             NaN
# 37070                                             NaN
# 37113                                             NaN
# 37142                                             NaN
# 37157                                             NaN
# 37233                                             NaN
# 38594                                             NaN
# 39003                                             NaN
# 39069                                             NaN
# 39714                                             NaN
# 44481                                             NaN
# 44640                                             NaN
# 45213                                             NaN
# 45771                                             NaN
# 47346  UNKNOWN - ANI/ALI - WRLS PHNS (INCL OPEN LINE)
# 48253                                             NaN
# 3932                                              NaN
# 5391                                              NaN
# 182                               NUISANCE - MISCHIEF
# 4602     PARKS VIOLATIONS/CITES (INCLUDES EXCLUSIONS)
# 4603     PARKS VIOLATIONS/CITES (INCLUDES EXCLUSIONS)
# 4604     PARKS VIOLATIONS/CITES (INCLUDES EXCLUSIONS)
# 4834                                              NaN
# 14331       THEFT (DOES NOT INCLUDE SHOPLIFT OR SVCS)
# 30286                                             NaN
# 30287                                             NaN
# 40407    PARKS VIOLATIONS/CITES (INCLUDES EXCLUSIONS)
# 40471   THREATS (INCLS IN-PERSON/BY PHONE/IN WRITING)
# 46320                DISTURBANCE, MISCELLANEOUS/OTHER
# 4638                 NOISE - DISTURBANCE (PARTY, ETC)
# 7672            ASLT - IP/JO - PERSON SHOT OR SHOT AT
#
#                                final_call_type                 call_type  \
# 1048                                       NaN                       NaN
# 1049                                       NaN                       NaN
# 1050                                       NaN                       NaN
# 1069                                       NaN                       NaN
# 3634                                       NaN                       NaN
# 7259                                       NaN                       NaN
# 9291                                       NaN                       NaN
# 11351                                      NaN                       NaN
# 11912                                      NaN                       NaN
# 12551                                      NaN                       NaN
# 20801                                      NaN                       NaN
# 25203                                      NaN                       NaN
# 25527                                      NaN                       NaN
# 27061                                      NaN                       NaN
# 27548                                      NaN                       NaN
# 28277                                      NaN                       NaN
# 28299                                      NaN                       NaN
# 30769                                      NaN                       NaN
# 31224                                      NaN                       NaN
# 36789                                      NaN                       NaN
# 37070                                      NaN                       NaN
# 37113                                      NaN                       NaN
# 37142                                      NaN                       NaN
# 37157                                      NaN                       NaN
# 37233                                      NaN                       NaN
# 38594                                      NaN                       NaN
# 39003                                      NaN                       NaN
# 39069                                      NaN                       NaN
# 39714                                      NaN                       NaN
# 44481                                      NaN                       NaN
# 44640                                      NaN                       NaN
# 45213                                      NaN                       NaN
# 45771                                      NaN                       NaN
# 47346                    --DISTURBANCE - OTHER  TELEPHONE OTHER, NOT 911
# 48253                                      NaN                       NaN
# 3932                                       NaN                       NaN
# 5391                                       NaN                       NaN
# 182                        NUISANCE - MISCHIEF                    ONVIEW
# 4602   --MISC MISD AND VIOLS - PARKS EXCLUSION                       911
# 4603   --MISC MISD AND VIOLS - PARKS EXCLUSION                       911
# 4604   --MISC MISD AND VIOLS - PARKS EXCLUSION                       911
# 4834                                       NaN                       NaN
# 14331   SUSPICIOUS PERSON, VEHICLE OR INCIDENT  TELEPHONE OTHER, NOT 911
# 30286                                      NaN                       NaN
# 30287                                      NaN                       NaN
# 40407  --MISC MISD AND VIOLS - PARKS EXCLUSION                       911
# 40471         --ASSAULTS - HARASSMENT, THREATS                       911
# 46320         DISTURBANCE, MISCELLANEOUS/OTHER                    ONVIEW
# 4638                     --DISTURBANCE - NOISE                       911
# 7672                         --ASSAULTS, OTHER                       911
#
#                          officer_squad arrest_flag frisk_flag   precinct  \
# 1048                               NaN           N          Y       West
# 1049                               NaN           N          Y       West
# 1050                               NaN           N          Y       West
# 1069                               NaN           N          N       East
# 3634                               NaN           N          N        NaN
# 7259                               NaN           N          N        NaN
# 9291                               NaN           N          N       West
# 11351                              NaN           N          N       East
# 11912                              NaN           N          N       West
# 12551                              NaN           N          N       West
# 20801  TRAINING - FIELD TRAINING SQUAD           N          N        NaN
# 25203                              NaN           Y          N      North
# 25527                              NaN           Y          N       West
# 27061                              NaN           N          N       West
# 27548                              NaN           N          N        NaN
# 28277                              NaN           N          N       West
# 28299                              NaN           N          N       West
# 30769                              NaN           N          N      North
# 31224                              NaN           N          N        NaN
# 36789                              NaN           N          N       West
# 37070                              NaN           N          N       West
# 37113                              NaN           Y          Y      South
# 37142                              NaN           N          N       West
# 37157                              NaN           N          Y        NaN
# 37233                              NaN           N          N       West
# 38594                              NaN           N          N       West
# 39003                              NaN           N          N       West
# 39069                              NaN           N          N       West
# 39714                              NaN           N          N       West
# 44481                              NaN           N          N       West
# 44640                              NaN           N          N       West
# 45213                              NaN           N          N       East
# 45771                              NaN           N          N       West
# 47346  TRAINING - FIELD TRAINING SQUAD           N          Y      North
# 48253                              NaN           N          N       East
# 3932                EAST PCT OPS - CPT           N          N       West
# 5391                EAST PCT OPS - CPT           N          N       West
# 182       NORTH PCT 1ST W - BOY (JOHN)           N          N      North
# 4602      NORTH PCT 1ST W - BOY (JOHN)           N          N        NaN
# 4603      NORTH PCT 1ST W - BOY (JOHN)           N          N        NaN
# 4604      NORTH PCT 1ST W - BOY (JOHN)           N          N        NaN
# 4834      NORTH PCT 1ST W - BOY (JOHN)           N          N      North
# 14331     NORTH PCT 1ST W - BOY (JOHN)           N          Y      North
# 30286     NORTH PCT 1ST W - BOY (JOHN)           N          N      North
# 30287     NORTH PCT 1ST W - BOY (JOHN)           N          N      North
# 40407     NORTH PCT 1ST W - BOY (JOHN)           N          N        NaN
# 40471     NORTH PCT 1ST W - BOY (JOHN)           N          N      North
# 46320     NORTH PCT 1ST W - BOY (JOHN)           N          N      North
# 4638       SOUTHWEST PCT 3RD W - FRANK           N          N  Southwest
# 7672           SOUTH PCT 3RD W - OCEAN           N          N      South
#
#        sector    beat
# 1048        K      K3
# 1049        K      K3
# 1050        K      K3
# 1069        E      E3
# 3634      NaN     NaN
# 7259      NaN     NaN
# 9291   Q       Q1
# 11351       E      E1
# 11912       M      M3
# 12551       M      M3
# 20801     NaN     NaN
# 25203       B      B1
# 25527       Q      Q2
# 27061       K      K3
# 27548     NaN     NaN
# 28277       D      D3
# 28299       D      D1
# 30769  N       N3
# 31224     NaN     NaN
# 36789       M      M3
# 37070       M      M3
# 37113       S      S1
# 37142       Q      Q2
# 37157     NaN     NaN
# 37233       Q      Q1
# 38594       M      M3
# 39003       K      K2
# 39069       D      D1
# 39714       D      D1
# 44481       M      M1
# 44640       Q      Q2
# 45213       E      E3
# 45771       M      M3
# 47346  B       B2
# 48253       E      E3
# 3932   K       K1
# 5391   K       K3
# 182    J       J3
# 4602      NaN     NaN
# 4603      NaN     NaN
# 4604      NaN     NaN
# 4834   N       N3
# 14331  J       J3
# 30286  U       U2
# 30287  U       U2
# 40407     NaN     NaN
# 40471  B       B3
# 46320  B       B1
# 4638   F       F1
# 7672   O       O3

# %%
# dropping rows where officer age is 121 bc there is insufficient data in those rows 

df.drop((df[df['officer_age'] == 121]).index, inplace = True)

# %%
# Convert reported_date column to datetime type

df['reported_date'] = pd.to_datetime(df['reported_date'], yearfirst=True)

# %%
# add columns for year and month from 'reported_date' column
df['year'] = df['reported_date'].dt.year
df['month'] = df['reported_date'].dt.month
df['year'] = df['year'].astype('object')
df['month'] = df['month'].astype('object')

# %%
# Convert Arrest and Frisk columns to 1's and 0's
df['arrest_flag'] = df['arrest_flag'].replace({'Y':1, 'N':0})
df['frisk_flag'] = df['frisk_flag'].replace({'Y':1, 'N':0})

# %% [markdown]
# ## Data Cleaning Episode 3: The Revenge of the CSV

# %% [markdown]
# The final part of the data cleaning process is to inspect the arrest flag column which will be our target and the the final dataframe which will be saved as a csv.

# %%
# inspecting value counts for arrest flag column
df['arrest_flag'].value_counts(dropna=False)
# Out:
# 0    44182
# 1     3830
# Name: arrest_flag, dtype: int64

# %%
# Final Inspection of Dataframe
df.shape
# Out:
# (48012, 21)

# %%
df.head()
# Out:
#   subject_age_group stop_resolution weapon_type officer_id  officer_age  \
# 0     Not Specified          Arrest        None     7500             37
# 1     Not Specified   Field Contact        None     5670             56
# 3     Not Specified   Field Contact        None     7539             58
# 4     Not Specified   Field Contact        None     6973             44
# 5     Not Specified   Field Contact        None     7402             48
#
#   officer_gender               officer_race     subject_perceived_race  \
# 0              M  Black or African American                      Asian
# 1              M                      White                    Unknown
# 3              M                      White                    Unknown
# 4              M                      White  Black or African American
# 5              M                      White  Black or African American
#
#   subject_perceived_gender reported_date initial_call_type final_call_type  \
# 0                     Male    2015-10-16               NaN             NaN
# 1                  Unknown    2015-03-19               NaN             NaN
# 3                  Unknown    2015-04-01               NaN             NaN
# 4                     Male    2015-04-03               NaN             NaN
# 5                     Male    2015-04-05               NaN             NaN
#
#   call_type             officer_squad  arrest_flag  frisk_flag precinct  \
# 0       NaN  SOUTH PCT 1ST W - ROBERT            0           0    South
# 1       NaN                       NaN            0           0      NaN
# 3       NaN                       NaN            0           0      NaN
# 4       NaN                       NaN            0           0      NaN
# 5       NaN                       NaN            0           0      NaN
#
#    sector    beat  year month
# 0  O       O2      2015    10
# 1     NaN     NaN  2015     3
# 3     NaN     NaN  2015     4
# 4     NaN     NaN  2015     4
# 5     NaN     NaN  2015     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48012 entries, 0 to 48524
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   subject_age_group         48012 non-null  object
#  1   stop_resolution           48012 non-null  object
#  2   weapon_type               48012 non-null  object
#  3   officer_id                48012 non-null  object
#  4   officer_age               48012 non-null  int64
#  5   officer_gender            48012 non-null  object
#  6   officer_race              48012 non-null  object
#  7   subject_perceived_race    48012 non-null  object
#  8   subject_perceived_gender  48012 non-null  object
#  9   reported_date             48012 non-null  datetime64[ns]
#  10  initial_call_type         35004 non-null  object
#  11  final_call_type           35004 non-null  object
#  12  call_type                 35004 non-null  object
#  13  officer_squad             47452 non-null  object
#  14  arrest_flag               48012 non-null  int64
#  15  frisk_flag                48012 non-null  int64
#  16  precinct                  38225 non-null  object
#  17  sector                    38018 non-null  object
#  18  beat                      38084 non-null  object
#  19  year                      48012 non-null  object
#  20  month                     48012 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(17)
# memory usage: 8.1+ MB

# %%
# save cleaned dataframe as a csv
df.to_csv('Terry_stops_cleaned.csv', index=False)
